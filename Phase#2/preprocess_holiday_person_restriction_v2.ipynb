# %%
import pandas as pd
import numpy as np
import glob
import datetime

# %% [markdown]
# # **Load**

# %%
restrictions_df = pd.read_csv("restrictions.csv", sep = ";", header = 0, usecols = [2,3,4,5,6])

restrictions_df.head(20)
# Out:
#    intervention_category  ...           start_date
# 0        Case management  ...  2020-08-14 00:00:00
# 1        Case management  ...  2020-09-11 00:00:00
# 2       Health workforce  ...  2020-08-04 00:00:00
# 3     Public information  ...  2020-08-12 00:00:00
# 4      Closures/openings  ...  2020-08-15 00:00:00
# 5             Distancing  ...  2020-08-21 00:00:00
# 6        Health services  ...  2020-08-28 00:00:00
# 7        Health services  ...  2020-09-09 00:00:00
# 8      Closures/openings  ...  2020-09-08 00:00:00
# 9             Distancing  ...  2020-09-18 00:00:00
# 10            Distancing  ...  2020-09-19 00:00:00
# 11     Closures/openings  ...  2020-09-26 00:00:00
# 12     Closures/openings  ...  2020-09-26 00:00:00
# 13      Health workforce  ...  2020-08-12 00:00:00
#
# [14 rows x 5 columns]

# %%
holiday_df = pd.read_csv("holiday.csv", sep = ";", header = 0, usecols = [2,3,4])
holiday_df.head()
# Out:
#           holiday_date                   name  statutory
# 0  2020-08-02 00:00:00      New Brunswick Day      False
# 1  2020-08-02 00:00:00  Federal Civic Holiday       True
# 2  2020-08-02 00:00:00          Terry Fox Day      False
# 3  2020-08-02 00:00:00       Saskatchewan Day      False
# 4  2020-08-02 00:00:00         Colonel By Day      False

# %%
patient_df = pd.read_csv("patient_data.csv", sep = ",", header = 0, usecols = [6,7,8])

patient_df.head()
# Out:
#   Age_Group Client_Gender Case_AcquisitionInfo
# 0       20s          MALE                   CC
# 1       50s          MALE                   CC
# 2       40s        FEMALE                   CC
# 3       <20        FEMALE    NO KNOWN EPI LINK
# 4       20s          MALE                   CC

# %% [markdown]
# # **Process**

# %% [markdown]
# **Restriction**

# %%
#insert id column
#restrictions_df.insert(0, 'restriction_id', range(0, len(restrictions_df)))

restrictions_df.set_index('restriction_id', inplace=True)

restrictions_df.head(20)
# Out:
#                intervention_category  ...           start_date
# restriction_id                        ...
# 0                    Case management  ...  2020-08-14 00:00:00
# 1                    Case management  ...  2020-09-11 00:00:00
# 2                   Health workforce  ...  2020-08-04 00:00:00
# 3                 Public information  ...  2020-08-12 00:00:00
# 4                  Closures/openings  ...  2020-08-15 00:00:00
# 5                         Distancing  ...  2020-08-21 00:00:00
# 6                    Health services  ...  2020-08-28 00:00:00
# 7                    Health services  ...  2020-09-09 00:00:00
# 8                  Closures/openings  ...  2020-09-08 00:00:00
# 9                         Distancing  ...  2020-09-18 00:00:00
# 10                        Distancing  ...  2020-09-19 00:00:00
# 11                 Closures/openings  ...  2020-09-26 00:00:00
# 12                 Closures/openings  ...  2020-09-26 00:00:00
# 13                  Health workforce  ...  2020-08-12 00:00:00
#
# [14 rows x 5 columns]

# %% [markdown]
# **Holiday**

# %%
holiday_df.insert(0, 'holiday_id', range(0, len(holiday_df)))

holiday_df.set_index('holiday_id', inplace=True)

holiday_df.head(20)
# Out:
#                    holiday_date                        name  statutory
# holiday_id
# 0           2020-08-02 00:00:00           New Brunswick Day      False
# 1           2020-08-02 00:00:00       Federal Civic Holiday       True
# 2           2020-08-02 00:00:00               Terry Fox Day      False
# 3           2020-08-02 00:00:00            Saskatchewan Day      False
# 4           2020-08-02 00:00:00              Colonel By Day      False
# 5           2020-08-02 00:00:00                   Natal Day      False
# 6           2020-08-02 00:00:00        British Columbia Day      False
# 7           2020-08-02 00:00:00        August Civic Holiday       True
# 8           2020-08-09 00:00:00  National Peacekeepers' Day      False
# 9           2020-08-20 00:00:00         Gold Cup Parade Day      False
# 10          2020-09-06 00:00:00                   Labor Day       True
# 11          2020-09-12 00:00:00  National Grandparents' Day      False
# 12          2020-09-22 00:00:00           September Equinox      False
# 13          2020-10-11 00:00:00            Thanksgiving Day       True
# 14          2020-10-31 00:00:00                   Halloween      False
# 15          2020-11-11 00:00:00               Armistice Day      False
# 16          2020-11-11 00:00:00             Remembrance Day      False

# %% [markdown]
# **Patient**

# %%
patient_df.columns = ['age_group', 'client_gender', 'case_acquisition']

patient_df = patient_df.drop_duplicates(['age_group', 'client_gender', 'case_acquisition'])


patient_df.insert(0, 'patient_id', range(0, len(patient_df)))

patient_df.set_index('patient_id', inplace=True)

print(patient_df.shape)
patient_df.head(20)
# Out:
# (178, 3)
#            age_group client_gender   case_acquisition
# patient_id
# 0                20s          MALE                 CC
# 1                50s          MALE                 CC
# 2                40s        FEMALE                 CC
# 3                <20        FEMALE  NO KNOWN EPI LINK
# 4                20s          MALE  NO KNOWN EPI LINK
# 5                30s        FEMALE                 CC
# 6                40s        FEMALE                 OB
# 7                <20        FEMALE                 CC
# 8                40s          MALE                 OB
# 9                30s          MALE  NO KNOWN EPI LINK
# 10               80s          MALE                 OB
# 11               90+        FEMALE                 OB
# 12               50s        FEMALE                 CC
# 13               30s          MALE                 CC
# 14               20s        FEMALE  NO KNOWN EPI LINK
# 15               60s          MALE  NO KNOWN EPI LINK
# 16               70s          MALE                 OB
# 17               20s          MALE                 OB
# 18               80s          MALE                 CC
# 19               30s          MALE                 OB

# %% [markdown]
# # **Export data**

# %%
holiday_df.to_excel("holiday_v2.xlsx")
restrictions_df.to_excel("restrictions_v2.xlsx")
patient_df.to_excel("patients_v2.xlsx")

# %% [markdown]
# # **DB Connection**

# %%
from sqlalchemy import create_engine, text
import psycopg2 
import io
from config2 import PASSWORD


engine = create_engine('postgresql://belha066:'+PASSWORD+'@www.eecs.uottawa.ca:15432/group_12')


#create tables from SQL file called schema.txt
def create_tables(engine):
    sql_file = open("schema2.sql")
    escaped_sql = text(sql_file.read())
    engine.execute(escaped_sql)
    
#load data from datafram to database
def push_df_to_db(engine, df, table_name):
    try:
        conn = engine.raw_connection()
        cur = conn.cursor()
        output = io.StringIO()
        df.to_csv(output, sep='\t', header=False, index=False)
        output.seek(0)
        contents = output.getvalue()
        cur.copy_from(output, table_name, null="") # null values become ''
        conn.commit()
    except Exception as e:
        print(e)
    finally:
        conn.close()

# %%
create_tables(engine)

# %%
push_df_to_db(engine, holiday_df, "holiday")
push_df_to_db(engine, patient_df, "person")
